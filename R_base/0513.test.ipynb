# %%
test <- read.csv('../data/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2018년.csv',header=T,fileEncoding='euc-kr')

# %%
(test[test$상권_구분_코드_명=='관광특구'&test$기준_년_코드==2018&test$기준_분기_코드==4&test$서비스_업종_코드_명=='호프-간이주점','분기당_매출_금액'])
# Out:
# [1] 20416606270 10764965359  2783451661 17843596012 10670348447
