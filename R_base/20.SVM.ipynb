# %%
# Anaconda Navigator에서 e1071 설치
# 선형회귀식, 표준화 작업 필요

# %%
library(e1071)

# %%
# Sampling, 학습용/검증용 만들기
library(caret)
iris2 <- as.data.frame(scale(iris[,-5]))
iris2$Species <- iris$Species
class(iris2)

samp <- createDataPartition(iris2$Species, p=0.7, list=F)
# 학습용
data.tr <- iris2[samp,]
head(data.tr)
tail(data.tr)
# 검증용
data.test <- iris2[-samp,]
head(data.test)
tail(data.test)
# Out:
# [1] "data.frame"
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 -0.8976739    1.01560199 -1.335752    -1.311052   setosa
# 2 -1.1392005   -0.13153881 -1.335752    -1.311052   setosa
# 3 -1.3807271    0.32731751 -1.392399    -1.311052   setosa
# 4 -1.5014904    0.09788935 -1.279104    -1.311052   setosa
# 6 -0.5353840    1.93331463 -1.165809    -1.048667   setosa
# 7 -1.5014904    0.78617383 -1.335752    -1.179859   setosa
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 143 -0.05233076  -0.8198233  0.7602115    0.9192234   virginica
# 144  1.15530226   0.3273175  1.2133927    1.4439941   virginica
# 145  1.03453895   0.5567457  1.1000974    1.7063794   virginica
# 147  0.55148575  -1.2786796  0.7035638    0.9192234   virginica
# 148  0.79301235  -0.1315388  0.8168591    1.0504160   virginica
# 149  0.43072244   0.7861738  0.9301544    1.4439941   virginica
#    Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 5  -1.0184372    1.2450302  -1.335752    -1.3110521  setosa
# 9  -1.7430170   -0.3609670  -1.335752    -1.3110521  setosa
# 13 -1.2599638   -0.1315388  -1.335752    -1.4422448  setosa
# 16 -0.1730941    3.0804554  -1.279104    -1.0486668  setosa
# 19 -0.1730941    1.7038865  -1.165809    -1.1798595  setosa
# 24 -0.8976739    0.5567457  -1.165809    -0.9174741  setosa
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 124 0.55148575   -0.81982329 0.6469162    0.7880307   virginica
# 125 1.03453895    0.55674567 1.1000974    1.1816087   virginica
# 136 2.24217198   -0.13153881 1.3266880    1.4439941   virginica
# 138 0.67224905    0.09788935 0.9868021    0.7880307   virginica
# 146 1.03453895   -0.13153881 0.8168591    1.4439941   virginica
# 150 0.06843254   -0.13153881 0.7602115    0.7880307   virginica

# %%
# 문제 및 정답 만들기
x <- subset(data.test, select=-Species)
y <- data.test$Species

# %%
# 학습하기
model.svm = svm(Species~., data=data.tr)

# %%
# 검증하기
pred <- predict(model.svm, x)

# %%
# 예측율 및 오분류표
mean(pred == y)
table(pred, y)
# Out:
# [1] 0.9333333
#             y
# pred         setosa versicolor virginica
#   setosa         15          0         0
#   versicolor      0         14         2
#   virginica       0          1        13
